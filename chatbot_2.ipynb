# %%
import pandas as pd
import json
json_string = """
{
  "intents": [
  {"tag": "greetings",
   "patterns": ["Hii", "Hey", "Hello", "What's going on", "Whats's up", "How you doing?"],
   "responses": ["Hey!", "How are you", "What can i do for you", "Hello"]
   },
  {
    "tag": "goodbye",
    "patterns":["see you later","goodbye","I am leaving","bye","tata","ciao","see ya"],
    "responses":["Goodbye!","Cao","Sayōnara","See you later"]
  },
  {
    "tag": "Name",
    "patterns":["Name","What is your name?","what should i call you?","Apka naam kya hai","cuál es tu nombre"],
    "responses":["My name is R","U can call me R"]
  },
  {
    "tag": "slang",
    "patterns":["fuck","fucker","chutiya","Harami"],
    "responses":["tu chutiya","tu madarchod","Go FUCK YOUR SELF SOME WHERE ELSE"]
 },
 {
    "tag": "language",
    "patterns" :["What language do you speak?","language","What do u speak?"],
    "responses":["I speak English","I loved to speak English","English","Some time I like to speak Spanish"]
 },
   {"tag": "age",
    "patterns": ["How old are you", "What is your age", "Age?"],
    "responses": ["I am 9!", "9 years old"]  
   },

   {"tag": "work",
   "patterns": ["What do you do", "What you like", "What give you happiness"],
   "responses": ["I'll work for you", "I would like to help you", "By helping you"]
   }

]}"""
data = json.loads(json_string)

# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer
nltk.download('punkt')
nltk.download('wordnet')

! pip install tensorflow==1.2.0
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Rishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Rishik\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.2.0 (from versions: 2.5.0rc0, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.8.0rc0, 2.8.0rc1, 2.8.0)
# ERROR: No matching distribution found for tensorflow==1.2.0

# %% [markdown]
# Python pickle module is used for serializing and de-serializing a Python object structure.
#
# NLTK (Natural Language Toolkit) Library is a suite that contains libraries and programs for statistical language processing
#
# Lemmatization is the process of grouping together the different inflected forms of a word so they can be analyzed as a single item
#
# Punkt This tokenizer divides a text into a list of sentences, by using an unsupervised algorithm to build a model
#
# Tensor It is a foundation library that can be used to create Deep Learning models directly or by using wrapper libraries that simplify the process built on top of TensorFlow.
#
# Stochastic Gradient Descent (SGD) is a simple yet very efficient approach to fitting linear classifiers and regressors under convex loss functions such as (linear) Support Vector Machines and Logistic Regression

# %%
  lemmatizer = WordNetLemmatizer()
  intents = data
words=[]
classes=[]
documents=[]
ignore_letters=['?','!','.',',']

# %%
for intent in intents['intents']:
  for pattern in intent['patterns']:
      word_list=nltk.word_tokenize(pattern)
      words.extend(word_list)
      documents.append((word_list, intent['tag']))
      if intent['tag'] not in classes:
          classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_letters]
words = sorted(set(words))

classes = sorted(set(classes))


pickle.dump(words, open('words.pkl' , 'wb'))
pickle.dump(classes, open('classes.pkl' , 'wb'))

training = []
output_empty = [0]* len(classes)

for document in documents:
  bag = []
  word_patterns = document[0]
  word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
  for word in words:
    bag.append(1) if word in word_patterns else bag.append(0)

    output_row = list(output_empty)
    output_row[classes.index(document[1])] = 1
    training.append([bag, output_row])


random.shuffle(training)
training = np.array(training)


train_x = list(training[:,0])
train_y = list(training[:,1])

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))


sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy']) 
hist=model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbotmodel.h5', hist)
print('Done')
# Out:
# C:\Users\Rishik\AppData\Local\Temp/ipykernel_8024/1985854122.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# C:\Users\Rishik\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Epoch 1/200
# 329/329 [==============================] - 1s 1ms/step - loss: 0.9993 - accuracy: 0.6476
# Epoch 2/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9404
# Epoch 3/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.1406 - accuracy: 0.9495
# Epoch 4/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.1254 - accuracy: 0.9550
# Epoch 5/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.1128 - accuracy: 0.9598
# Epoch 6/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.1100 - accuracy: 0.9629
# Epoch 7/200
# 329/329 [==============================] - 0s 977us/step - loss: 0.1012 - accuracy: 0.9592
# Epoch 8/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 0.9635
# Epoch 9/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0991 - accuracy: 0.9635
# Epoch 10/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9623
# Epoch 11/200
# 329/329 [==============================] - 0s 988us/step - loss: 0.0915 - accuracy: 0.9629
# Epoch 12/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9665
# Epoch 13/200
# 329/329 [==============================] - 0s 986us/step - loss: 0.0833 - accuracy: 0.9671
# Epoch 14/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9677
# Epoch 15/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0832 - accuracy: 0.9623
# Epoch 16/200
# 329/329 [==============================] - 0s 959us/step - loss: 0.0852 - accuracy: 0.9647
# Epoch 17/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0837 - accuracy: 0.9653
# Epoch 18/200
# 329/329 [==============================] - 0s 985us/step - loss: 0.0853 - accuracy: 0.9659
# Epoch 19/200
# 329/329 [==============================] - 0s 940us/step - loss: 0.0832 - accuracy: 0.9671
# Epoch 20/200
# 329/329 [==============================] - 0s 961us/step - loss: 0.0840 - accuracy: 0.9647
# Epoch 21/200
# 329/329 [==============================] - 0s 933us/step - loss: 0.0843 - accuracy: 0.9647
# Epoch 22/200
# 329/329 [==============================] - 0s 962us/step - loss: 0.0824 - accuracy: 0.9665
# Epoch 23/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9623
# Epoch 24/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0858 - accuracy: 0.9659
# Epoch 25/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0792 - accuracy: 0.9677
# Epoch 26/200
# 329/329 [==============================] - 0s 939us/step - loss: 0.0804 - accuracy: 0.9671
# Epoch 27/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0801 - accuracy: 0.9677
# Epoch 28/200
# 329/329 [==============================] - 0s 999us/step - loss: 0.0781 - accuracy: 0.9641
# Epoch 29/200
# 329/329 [==============================] - 0s 960us/step - loss: 0.0793 - accuracy: 0.9671
# Epoch 30/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 0.9677
# Epoch 31/200
# 329/329 [==============================] - 0s 985us/step - loss: 0.0819 - accuracy: 0.9671
# Epoch 32/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9671
# Epoch 33/200
# 329/329 [==============================] - 0s 989us/step - loss: 0.0804 - accuracy: 0.9641
# Epoch 34/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9659
# Epoch 35/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9665
# Epoch 36/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9684
# Epoch 37/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9671
# Epoch 38/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0809 - accuracy: 0.9665
# Epoch 39/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0801 - accuracy: 0.9665
# Epoch 40/200
# 329/329 [==============================] - 0s 991us/step - loss: 0.0784 - accuracy: 0.9677
# Epoch 41/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0766 - accuracy: 0.9671
# Epoch 42/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9665
# Epoch 43/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9665
# Epoch 44/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 0.9677
# Epoch 45/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.9677
# Epoch 46/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9671
# Epoch 47/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9671
# Epoch 48/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9677
# Epoch 49/200
# 329/329 [==============================] - 0s 907us/step - loss: 0.0766 - accuracy: 0.9677
# Epoch 50/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0773 - accuracy: 0.9671
# Epoch 51/200
# 329/329 [==============================] - 0s 920us/step - loss: 0.0752 - accuracy: 0.9684
# Epoch 52/200
# 329/329 [==============================] - 0s 985us/step - loss: 0.0783 - accuracy: 0.9677
# Epoch 53/200
# 329/329 [==============================] - 0s 910us/step - loss: 0.0760 - accuracy: 0.9677
# Epoch 54/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9665
# Epoch 55/200
# 329/329 [==============================] - 0s 894us/step - loss: 0.0778 - accuracy: 0.9671
# Epoch 56/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.9671
# Epoch 57/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9677
# Epoch 58/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9677
# Epoch 59/200
# 329/329 [==============================] - 0s 983us/step - loss: 0.0761 - accuracy: 0.9671
# Epoch 60/200
# 329/329 [==============================] - 0s 966us/step - loss: 0.0757 - accuracy: 0.9671
# Epoch 61/200
# 329/329 [==============================] - 0s 998us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 62/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.9671
# Epoch 63/200
# 329/329 [==============================] - 0s 993us/step - loss: 0.0740 - accuracy: 0.9677
# Epoch 64/200
# 329/329 [==============================] - 0s 988us/step - loss: 0.0779 - accuracy: 0.9677
# Epoch 65/200
# 329/329 [==============================] - 0s 912us/step - loss: 0.0744 - accuracy: 0.9677
# Epoch 66/200
# 329/329 [==============================] - 0s 987us/step - loss: 0.0755 - accuracy: 0.9665
# Epoch 67/200
# 329/329 [==============================] - 0s 988us/step - loss: 0.0757 - accuracy: 0.9671
# Epoch 68/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 0.9677
# Epoch 69/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 0.9665
# Epoch 70/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0773 - accuracy: 0.9665
# Epoch 71/200
# 329/329 [==============================] - 0s 963us/step - loss: 0.0774 - accuracy: 0.9665
# Epoch 72/200
# 329/329 [==============================] - 0s 913us/step - loss: 0.0786 - accuracy: 0.9671
# Epoch 73/200
# 329/329 [==============================] - 0s 912us/step - loss: 0.0753 - accuracy: 0.9677
# Epoch 74/200
# 329/329 [==============================] - 0s 914us/step - loss: 0.0781 - accuracy: 0.9671
# Epoch 75/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9677
# Epoch 76/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9659
# Epoch 77/200
# 329/329 [==============================] - 0s 888us/step - loss: 0.0752 - accuracy: 0.9671
# Epoch 78/200
# 329/329 [==============================] - 0s 984us/step - loss: 0.0759 - accuracy: 0.9677
# Epoch 79/200
# 329/329 [==============================] - 0s 908us/step - loss: 0.0765 - accuracy: 0.9671
# Epoch 80/200
# 329/329 [==============================] - 0s 959us/step - loss: 0.0758 - accuracy: 0.9677
# Epoch 81/200
# 329/329 [==============================] - 0s 913us/step - loss: 0.0764 - accuracy: 0.9677
# Epoch 82/200
# 329/329 [==============================] - 0s 914us/step - loss: 0.0759 - accuracy: 0.9665
# Epoch 83/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0749 - accuracy: 0.9671
# Epoch 84/200
# 329/329 [==============================] - 0s 913us/step - loss: 0.0771 - accuracy: 0.9665
# Epoch 85/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9665
# Epoch 86/200
# 329/329 [==============================] - 0s 926us/step - loss: 0.0770 - accuracy: 0.9677
# Epoch 87/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.9677
# Epoch 88/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9671
# Epoch 89/200
# 329/329 [==============================] - 0s 950us/step - loss: 0.0770 - accuracy: 0.9671
# Epoch 90/200
# 329/329 [==============================] - 0s 999us/step - loss: 0.0761 - accuracy: 0.9677
# Epoch 91/200
# 329/329 [==============================] - 0s 974us/step - loss: 0.0761 - accuracy: 0.9671
# Epoch 92/200
# 329/329 [==============================] - 0s 999us/step - loss: 0.0748 - accuracy: 0.9677
# Epoch 93/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0765 - accuracy: 0.9677
# Epoch 94/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 95/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9671
# Epoch 96/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0748 - accuracy: 0.9677
# Epoch 97/200
# 329/329 [==============================] - 0s 986us/step - loss: 0.0766 - accuracy: 0.9677
# Epoch 98/200
# 329/329 [==============================] - 0s 957us/step - loss: 0.0758 - accuracy: 0.9677
# Epoch 99/200
# 329/329 [==============================] - 0s 947us/step - loss: 0.0755 - accuracy: 0.9677
# Epoch 100/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0747 - accuracy: 0.9677
# Epoch 101/200
# 329/329 [==============================] - 0s 885us/step - loss: 0.0765 - accuracy: 0.9677
# Epoch 102/200
# 329/329 [==============================] - 0s 960us/step - loss: 0.0761 - accuracy: 0.9671
# Epoch 103/200
# 329/329 [==============================] - 0s 885us/step - loss: 0.0740 - accuracy: 0.9677
# Epoch 104/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0770 - accuracy: 0.9671
# Epoch 105/200
# 329/329 [==============================] - 0s 884us/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 106/200
# 329/329 [==============================] - 0s 988us/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 107/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9671
# Epoch 108/200
# 329/329 [==============================] - 0s 954us/step - loss: 0.0766 - accuracy: 0.9677
# Epoch 109/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9677
# Epoch 110/200
# 329/329 [==============================] - 0s 942us/step - loss: 0.0760 - accuracy: 0.9665
# Epoch 111/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 0.9665
# Epoch 112/200
# 329/329 [==============================] - 0s 980us/step - loss: 0.0754 - accuracy: 0.9677
# Epoch 113/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0753 - accuracy: 0.9677
# Epoch 114/200
# 329/329 [==============================] - 0s 951us/step - loss: 0.0736 - accuracy: 0.9677
# Epoch 115/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 116/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9677
# Epoch 117/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0764 - accuracy: 0.9671
# Epoch 118/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9671
# Epoch 119/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0767 - accuracy: 0.9671
# Epoch 120/200
# 329/329 [==============================] - 0s 975us/step - loss: 0.0765 - accuracy: 0.9671
# Epoch 121/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 122/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0742 - accuracy: 0.9677
# Epoch 123/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0737 - accuracy: 0.9677
# Epoch 124/200
# 329/329 [==============================] - 0s 1000us/step - loss: 0.0754 - accuracy: 0.9677
# Epoch 125/200
# 329/329 [==============================] - 0s 951us/step - loss: 0.0742 - accuracy: 0.9677
# Epoch 126/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0766 - accuracy: 0.9665
# Epoch 127/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0748 - accuracy: 0.9671
# Epoch 128/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 0.9665
# Epoch 129/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0757 - accuracy: 0.9671
# Epoch 130/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9665
# Epoch 131/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9677
# Epoch 132/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0766 - accuracy: 0.9677
# Epoch 133/200
# 329/329 [==============================] - 0s 2ms/step - loss: 0.0753 - accuracy: 0.9671
# Epoch 134/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 135/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9677
# Epoch 136/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.9665
# Epoch 137/200
# 329/329 [==============================] - 0s 999us/step - loss: 0.0753 - accuracy: 0.9671
# Epoch 138/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0741 - accuracy: 0.9677
# Epoch 139/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9671
# Epoch 140/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 141/200
# 329/329 [==============================] - 0s 986us/step - loss: 0.0751 - accuracy: 0.9671
# Epoch 142/200
# 329/329 [==============================] - 0s 987us/step - loss: 0.0747 - accuracy: 0.9677
# Epoch 143/200
# 329/329 [==============================] - 0s 982us/step - loss: 0.0737 - accuracy: 0.9671
# Epoch 144/200
# 329/329 [==============================] - 0s 911us/step - loss: 0.0760 - accuracy: 0.9677
# Epoch 145/200
# 329/329 [==============================] - 0s 963us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 146/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0733 - accuracy: 0.9677
# Epoch 147/200
# 329/329 [==============================] - 0s 959us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 148/200
# 329/329 [==============================] - 0s 936us/step - loss: 0.0773 - accuracy: 0.9671
# Epoch 149/200
# 329/329 [==============================] - 0s 972us/step - loss: 0.0753 - accuracy: 0.9677
# Epoch 150/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9671
# Epoch 151/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0744 - accuracy: 0.9677
# Epoch 152/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 153/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9677
# Epoch 154/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0741 - accuracy: 0.9677
# Epoch 155/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 156/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 157/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0756 - accuracy: 0.9671
# Epoch 158/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9677
# Epoch 159/200
# 329/329 [==============================] - 0s 911us/step - loss: 0.0735 - accuracy: 0.9677
# Epoch 160/200
# 329/329 [==============================] - 0s 960us/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 161/200
# 329/329 [==============================] - 0s 960us/step - loss: 0.0775 - accuracy: 0.9665
# Epoch 162/200
# 329/329 [==============================] - 0s 967us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 163/200
# 329/329 [==============================] - 0s 934us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 164/200
# 329/329 [==============================] - 0s 936us/step - loss: 0.0743 - accuracy: 0.9677
# Epoch 165/200
# 329/329 [==============================] - 0s 985us/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 166/200
# 329/329 [==============================] - 0s 942us/step - loss: 0.0744 - accuracy: 0.9677
# Epoch 167/200
# 329/329 [==============================] - 0s 981us/step - loss: 0.0745 - accuracy: 0.9671
# Epoch 168/200
# 329/329 [==============================] - 0s 913us/step - loss: 0.0767 - accuracy: 0.9671
# Epoch 169/200
# 329/329 [==============================] - 0s 959us/step - loss: 0.0746 - accuracy: 0.9677
# Epoch 170/200
# 329/329 [==============================] - 0s 935us/step - loss: 0.0752 - accuracy: 0.9665
# Epoch 171/200
# 329/329 [==============================] - 0s 986us/step - loss: 0.0776 - accuracy: 0.9665
# Epoch 172/200
# 329/329 [==============================] - 0s 962us/step - loss: 0.0732 - accuracy: 0.9677
# Epoch 173/200
# 329/329 [==============================] - 0s 967us/step - loss: 0.0743 - accuracy: 0.9677
# Epoch 174/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9671
# Epoch 175/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 176/200
# 329/329 [==============================] - 0s 964us/step - loss: 0.0741 - accuracy: 0.9677
# Epoch 177/200
# 329/329 [==============================] - 0s 913us/step - loss: 0.0740 - accuracy: 0.9677
# Epoch 178/200
# 329/329 [==============================] - 0s 960us/step - loss: 0.0749 - accuracy: 0.9677
# Epoch 179/200
# 329/329 [==============================] - 0s 976us/step - loss: 0.0751 - accuracy: 0.9677
# Epoch 180/200
# 329/329 [==============================] - 0s 956us/step - loss: 0.0756 - accuracy: 0.9671
# Epoch 181/200
# 329/329 [==============================] - 0s 932us/step - loss: 0.0734 - accuracy: 0.9677
# Epoch 182/200
# 329/329 [==============================] - 0s 979us/step - loss: 0.0783 - accuracy: 0.9665
# Epoch 183/200
# 329/329 [==============================] - 0s 959us/step - loss: 0.0748 - accuracy: 0.9677
# Epoch 184/200
# 329/329 [==============================] - 0s 983us/step - loss: 0.0747 - accuracy: 0.9677
# Epoch 185/200
# 329/329 [==============================] - 0s 989us/step - loss: 0.0727 - accuracy: 0.9677
# Epoch 186/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 187/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0733 - accuracy: 0.9677
# Epoch 188/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9677
# Epoch 189/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0750 - accuracy: 0.9677
# Epoch 190/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 191/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0741 - accuracy: 0.9677
# Epoch 192/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0761 - accuracy: 0.9671
# Epoch 193/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 0.9677
# Epoch 194/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0734 - accuracy: 0.9677
# Epoch 195/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0745 - accuracy: 0.9677
# Epoch 196/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 0.9677
# Epoch 197/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 0.9665
# Epoch 198/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0747 - accuracy: 0.9677
# Epoch 199/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0752 - accuracy: 0.9677
# Epoch 200/200
# 329/329 [==============================] - 0s 1ms/step - loss: 0.0736 - accuracy: 0.9677
# Done

# %%
from tensorflow.keras.models import load_model


lemmatizer = WordNetLemmatizer()
intents =data

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbotmodel.h5')


def clean_up_sentence(sentence):
  sentence_words = nltk.word_tokenize(sentence)
  sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
  return sentence_words

def bag_of_words(sentence):
  sentence_words = clean_up_sentence(sentence)
  bag = [0] * len(words)
  for w in sentence_words:
    for i,word in enumerate(words):
      if word == w:
        bag[i] = 1
  return np.array(bag)


def predict_class(sentence):
    bow = bag_of_words(sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results  =[[i, r] for i, r in enumerate(res) if r> ERROR_THRESHOLD]


    results.sort(key=lambda x: x[1], reverse=True)
    return_list=[]
    for r in results:
        return_list.append({'intent': classes[r[0]],'probability':str(r[1])})
    return return_list

def get_responses(intents_list,intents_json):
   tag=intents_list[0]['intent']
   list_of_intents=intents_json['intents']
   for i in list_of_intents:
       if i in list_of_intents:
          if i['tag']==tag:
              result=random.choice(i['responses'])
              break
   return result

print("GO! BOT is running!")
# Out:
# GO! BOT is running!

# %%
from tkinter import *
chat=Tk()
chat.title("Chat_Bot")
chat.geometry("400x600")
chat.minsize(450,450)
chat.maxsize(800,1200)
#function
def pri():
    ic=str(store.get())
    message = ic
    ints = predict_class(message)
    res= get_responses(ints,intents) 
    frame=Frame(chat,width=1200,height=500)
    frame.pack(anchor="ne")
    message_box = Message(frame, text=storage.get(),width=1200,relief=RIDGE)
    message_box.pack(fill=X)
    
    fram=Frame(chat,width=1200,height=500)
    fram.pack(anchor="nw")
    message_bo = Message(fram, text=res,width=1200,relief=RIDGE)
    message_bo.pack(fill=X)
    
    
    store.delete(0, END)
#head
head=Label(chat,text="WELCOME TO THE R CHAT BOT",font=("Algerian",18,"bold"))
head.pack(side=TOP)
#button
frame=Frame(chat,bg="gray",width=1200,height=500)
frame.pack(side="bottom",anchor="se")
but=Button(frame,text="Sent",width=1200,command=pri)
but.pack(anchor="se",side="bottom")
chat.bind('<Return>',but)
#chat bar
storage=StringVar()

store=Entry(chat, textvariable=storage ,font="200",width=1200)
store.pack(anchor="sw",side="bottom")

#scroll

chat.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Rishik\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: 'Button' object is not callable
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Rishik\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: 'Button' object is not callable
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Rishik\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
# TypeError: 'Button' object is not callable
